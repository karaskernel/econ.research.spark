# %%
import sys
import time
from pyspark.sql import SQLContext
from pyspark import SparkContext
from pyspark.sql.types import StringType
from pyspark.sql import SparkSession
import socket

spark = SparkSession.builder\
            .appName("Running SQL Queries in PySpark")\
            .master("spark://login1.cluster:7077")\
            .getOrCreate()
spark.conf.set('spark.sql.caseSensitive', True)
sc = spark.sparkContext
sc.setLogLevel("INFO")  # change this to WARN for less verbosity
print('======== START ========')
start = time.time()
print("Hello from ", socket.gethostname())
print("======== ELAPSED TIME: ", time.time() - start)
# Out:
# ======== START ========
# Hello from  login1.cluster
# ======== ELAPSED TIME:  0.00028777122497558594

# %%
# connecting the dir with data
raw_data = sc.textFile("file:///scratch/jkarasev/data-copy/works/updated_date=2024-01-10")

# %%
# looking at string
raw_data.take(1)
# Out:
# ['{"id": "https://openalex.org/W2125284466", "doi": "https://doi.org/10.1038/nature04233", "doi_registration_agency": "Crossref", "display_name": "Two-dimensional gas of massless Dirac fermions in graphene", "title": "Two-dimensional gas of massless Dirac fermions in graphene", "publication_year": 2005, "publication_date": "2005-11-01", "language": "en", "ids": {"openalex": "https://openalex.org/W2125284466", "doi": "https://doi.org/10.1038/nature04233", "pmid": "https://pubmed.ncbi.nlm.nih.gov/16281030", "mag": 2125284466, "arxiv_id": "arXiv:cond-mat/0509330"}, "primary_location": {"source": {"id": "https://openalex.org/S137773608", "issn_l": "0028-0836", "issn": ["1476-4687", "0028-0836"], "display_name": "Nature", "publisher": "Nature Portfolio", "host_organization": "https://openalex.org/P4310319908", "host_organization_name": "Nature Portfolio", "host_organization_lineage": ["https://openalex.org/P4310319908", "https://openalex.org/P4310319965"], "host_organization_lineage_names
# ...

# %%
# converting to dic
import json
rdd = raw_data.map(json.loads)
# rdd.persist() # can't get it to save in memory

# %%
# show 2
rdd.take(2)
# Out:
# [{'id': 'https://openalex.org/W2125284466',
#   'doi': 'https://doi.org/10.1038/nature04233',
#   'doi_registration_agency': 'Crossref',
#   'display_name': 'Two-dimensional gas of massless Dirac fermions in graphene',
#   'title': 'Two-dimensional gas of massless Dirac fermions in graphene',
#   'publication_year': 2005,
#   'publication_date': '2005-11-01',
#   'language': 'en',
#   'ids': {'openalex': 'https://openalex.org/W2125284466',
#    'doi': 'https://doi.org/10.1038/nature04233',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16281030',
#    'mag': 2125284466,
#    'arxiv_id': 'arXiv:cond-mat/0509330'},
#   'primary_location': {'source': {'id': 'https://openalex.org/S137773608',
#     'issn_l': '0028-0836',
#     'issn': ['1476-4687', '0028-0836'],
#     'display_name': 'Nature',
#     'publisher': 'Nature Portfolio',
#     'host_organization': 'https://openalex.org/P4310319908',
#     'host_organization_name': 'Nature Portfolio',
# ...

# %%
# Out:
# ['{"id": "https://openalex.org/W2125284466", "doi": "https://doi.org/10.1038/nature04233", "doi_registration_agency": "Crossref", "display_name": "Two-dimensional gas of massless Dirac fermions in graphene", "title": "Two-dimensional gas of massless Dirac fermions in graphene", "publication_year": 2005, "publication_date": "2005-11-01", "language": "en", "ids": {"openalex": "https://openalex.org/W2125284466", "doi": "https://doi.org/10.1038/nature04233", "pmid": "https://pubmed.ncbi.nlm.nih.gov/16281030", "mag": 2125284466, "arxiv_id": "arXiv:cond-mat/0509330"}, "primary_location": {"source": {"id": "https://openalex.org/S137773608", "issn_l": "0028-0836", "issn": ["1476-4687", "0028-0836"], "display_name": "Nature", "publisher": "Nature Portfolio", "host_organization": "https://openalex.org/P4310319908", "host_organization_name": "Nature Portfolio", "host_organization_lineage": ["https://openalex.org/P4310319908", "https://openalex.org/P4310319965"], "host_organization_lineage_names
# ...
